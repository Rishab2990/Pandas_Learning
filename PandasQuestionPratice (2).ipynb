# %%
# Question-1 :- Load CSV file and display the first five rows
import pandas as pd

# %%
readData = pd.read_csv('./Students_Grading_Dataset.csv')
readData.head(5)
# readData.info
# Out:
#   Student_ID First_Name Last_Name                    Email  Gender  Age  \
# 0      S1000       Omar  Williams  student0@university.com  Female   22
# 1      S1001      Maria     Brown  student1@university.com    Male   18
# 2      S1002      Ahmed     Jones  student2@university.com    Male   24
# 3      S1003       Omar  Williams  student3@university.com  Female   24
# 4      S1004       John     Smith  student4@university.com  Female   23
#
#     Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0  Engineering           52.29          55.03        57.82  ...
# 1  Engineering           97.27          97.23        45.80  ...
# 2     Business           57.19          67.05        93.68  ...
# 3  Mathematics           95.15          47.79        80.63  ...
# 4           CS           54.18          46.59        78.89  ...
#
#    Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# 0           85.90        56.09      F                   6.2
# ...

# %%
# Data Selection & Filtering =  find all passenger older than 30 on the ship, Titanic Dataset 
readData = pd.read_csv('./train.csv')
older_passengers = readData[readData['Age']>30]
older_passengers.head(5)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 4             5         0       3
# 6             7         0       1
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 4       0    373450   8.0500   NaN        S
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S

# %%
readData.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
readData.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 715          716         0       3
# 430          431         1       1
# 619          620         0       2
# 544          545         0       1
# 106          107         1       3
# 228          229         0       2
# 377          378         0       1
# 48            49         0       3
# 388          389         0       3
# 360          361         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 715  Soholt, Mr. Peter Andreas Lauritz Andersen    male  19.0      0      0
# 430   Bjornstrom-Steffansson, Mr. Mauritz Hakan    male  28.0      0      0
# 619                         Gavey, Mr. Lawrence    male  26.0      0      0
# 544                  Douglas, Mr. Walter Donald    male  50.0      1      0
# 106            Salkjelsvik, Miss. Anna Kristine  female  21.0      0      0
# 228                   Fahlstrom, Mr. Arne Jonas    male  18.0      0      0
# ...

# %%
readData.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
readData.notnull()
# Out:
#      PassengerId  Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  \
# 0           True      True    True  True  True   True   True   True    True
# 1           True      True    True  True  True   True   True   True    True
# 2           True      True    True  True  True   True   True   True    True
# 3           True      True    True  True  True   True   True   True    True
# 4           True      True    True  True  True   True   True   True    True
# ..           ...       ...     ...   ...   ...    ...    ...    ...     ...
# 886         True      True    True  True  True   True   True   True    True
# 887         True      True    True  True  True   True   True   True    True
# 888         True      True    True  True  True  False   True   True    True
# 889         True      True    True  True  True   True   True   True    True
# 890         True      True    True  True  True   True   True   True    True
#
#      Fare  Cabin  Embarked
# 0    True  False      True
# ...

# %%
# dropna() is a Method or function which helps us to remove the Null or Nan values from data 
readData.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
 fare=readData.groupby('Pclass')['Fare' ].mean()#agg(['sum' , 'mean'])
fare
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
# Merge Two Datasets based on a common columns

df1 = pd.DataFrame({
    'id' :[1,2,3,4,5,6,7],
  'name' :['Rishab', 'AGI', 'ASI', 'AI', 'Artificial Intelligence', 'Artificial Super Intelligence', 'Artificial General Intelligence'] 
})

df2 = pd.DataFrame({
    'id' : [4,5,6,7,8,9,10],
  'name' : ['World Top', 'Tech Organisations', 'Work On', 'AI, AGI, ASI to change the worlds', 'and create a big impact', 'which is crazy','it help a lot ']
})

mergingDF=pd.merge(df1 , df2 , how='right' , on='id')
mergingDF
# Out:
#    id                           name_x                             name_y
# 0   4                               AI                          World Top
# 1   5          Artificial Intelligence                 Tech Organisations
# 2   6    Artificial Super Intelligence                            Work On
# 3   7  Artificial General Intelligence  AI, AGI, ASI to change the worlds
# 4   8                              NaN            and create a big impact
# 5   9                              NaN                     which is crazy
# 6  10                              NaN                     it help a lot

# %%
# dropna() is a Method or function which helps us to remove the Null or Nan values from data 
mergingDF.dropna()
# Out:
#    id                           name_x                             name_y
# 3   4                               AI                          World Top
# 4   5          Artificial Intelligence                 Tech Organisations
# 5   6    Artificial Super Intelligence                            Work On
# 6   7  Artificial General Intelligence  AI, AGI, ASI to change the worlds

# %%
readData.loc[0 , 'Fare']
# Out:
# 30.0

# %%
readData.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171  30.0000   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
readData.fillna(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3 = pd.DataFrame ({
    'id':[1,2,3,4,5],
    'Name':['Braund,Mr.Owen Harris', 'Cumings, Mrs. john Bradley', 'Heikkinen,Miss. Laina','Futrelle, Mrs. Jacques Heath', 'Allen, Mr. William Henry']
})

df4 = pd.DataFrame ({
    'id' :[3,4,5,6,7],
    'Age':[22.0 , 38.0, 26.0 , 35.0 , 35.0]
})

df5 = pd.DataFrame({
    'id' : [3,4,5,6,7],
 'Cabin' : [5, 'C85' ,5 , 'C123' ,5]
})

df6 = pd.DataFrame({
    'id' : [3,4,5,6,7],
 'Cabin' : [5, 'C85' ,5 , 'C123' ,5]
})

mergedData =pd.merge(pd.merge(pd.merge(df3 , df4 , how='outer' , on='id'), df5, how ='outer' , on='id'), df6, how='outer' , on='id')
mergedData
# Out:
#    id                          Name   Age Cabin_x Cabin_y
# 0   1         Braund,Mr.Owen Harris   NaN     NaN     NaN
# 1   2    Cumings, Mrs. john Bradley   NaN     NaN     NaN
# 2   3         Heikkinen,Miss. Laina  22.0       5       5
# 3   4  Futrelle, Mrs. Jacques Heath  38.0     C85     C85
# 4   5      Allen, Mr. William Henry  26.0       5       5
# 5   6                           NaN  35.0    C123    C123
# 6   7                           NaN  35.0       5       5

# %%
# Import datetime module and import numpy as well
from datetime import datetime
import numpy as np

# %%
#  I think 'periods' and 'end'  are the same use but a different name 
rangeData = pd.date_range(start = '20/3/2025' , end='30/3/2025', freq = 'd')
rangeData
print(type(rangeData))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
df = pd.DataFrame([['Rishab' , 18 , 'Delhi'], ['Suraj' , 19 , 'Mumbai'], ['Rohan', 20 , 'Rajasthan'], ['Vishal' , 21 , 'Gwalior'],
                    ['Mukesh', 22, 'Goa']], columns=['Name', 'Age', 'City'])
print(df)
# df.Name
df['Name']
# Out:
#      Name  Age       City
# 0  Rishab   18      Delhi
# 1   Suraj   19     Mumbai
# 2   Rohan   20  Rajasthan
# 3  Vishal   21    Gwalior
# 4  Mukesh   22        Goa
# 0    Rishab
# 1     Suraj
# 2     Rohan
# 3    Vishal
# 4    Mukesh
# Name: Name, dtype: object

# %%
readFiles = pd.read_csv('test.csv')
readFiles
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
readFiles.index
readFiles.shape()
# Out:
# (418, 11)

# %%
readFiles.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# SHOW THE DATATYPE OF EACH COLUMN IN DATAFRAME
readData.head()
print(type('PassengerID'))
readData.dtypes
# Out:
# <class 'str'>
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
print(readData.columns)
print(readData.shape)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# (891, 12)

# %%
#This is a DataFrame
# userInfo = ([['Rishab' , 'Singh' , 'Rathor'] , ['AI' , 'AGI' , 'ASI']] , columns=['Name','Value', 'Info'])
# userInfo
# type(userInfo)
#This is dictionary
dictionary = {'Name' :'Rishab',
              'value' :  45,
              'info' : 'novamind'}

dictionary

#The way to check the type
type(dictionary)

# Converted Dictionary to DataFrame
change = pd.DataFrame([dictionary])
type(change)
# Out:
# pandas.core.frame.DataFrame

# %%
# Select a specific column from a dataFrame
readData.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# list(readData.index)
# list(readData.columns)
# list(readData.Name)
#readData.columns(4)
readData.loc[:,'Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# Select 3 rows using iloc[]
readData.iloc[:8 , [5,6,7,8]]
# Out:
#     Age  SibSp  Parch            Ticket
# 0  22.0      1      0         A/5 21171
# 1  38.0      1      0          PC 17599
# 2  26.0      0      0  STON/O2. 3101282
# 3  35.0      1      0            113803
# 4  35.0      0      0            373450
# 5   NaN      0      0            330877
# 6  54.0      0      0             17463
# 7   2.0      3      1            349909

# %%
# Select rows where age is less then 25
# age = readData[readData['Age']<25]
# age
difference = readData.loc[readData['Age']<25]
difference
# This code return boolean conditioning only not filtering 
# age = readData['Age']<25
# age
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com  Female   22
# 1         S1001      Maria     Brown     student1@university.com    Male   18
# 2         S1002      Ahmed     Jones     student2@university.com    Male   24
# 3         S1003       Omar  Williams     student3@university.com  Female   24
# 4         S1004       John     Smith     student4@university.com  Female   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com    Male   19
# 4996      S5996       Emma     Brown  student4996@university.com    Male   19
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4998      S5998       Sara     Davis  student4998@university.com    Male   23
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
# ...

# %%
readData.head()
# Out:
#   Student_ID First_Name Last_Name                    Email  Gender  Age  \
# 0      S1000       Omar  Williams  student0@university.com  Female   22
# 1      S1001      Maria     Brown  student1@university.com    Male   18
# 2      S1002      Ahmed     Jones  student2@university.com    Male   24
# 3      S1003       Omar  Williams  student3@university.com  Female   24
# 4      S1004       John     Smith  student4@university.com  Female   23
#
#     Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0  Engineering           52.29          55.03        57.82  ...
# 1  Engineering           97.27          97.23        45.80  ...
# 2     Business           57.19          67.05        93.68  ...
# 3  Mathematics           95.15          47.79        80.63  ...
# 4           CS           54.18          46.59        78.89  ...
#
#    Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# 0           85.90        56.09      F                   6.2
# ...

# %%
# summary of the data
readData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   First_Name                  5000 non-null   object
#  2   Last_Name                   5000 non-null   object
#  3   Email                       5000 non-null   object
#  4   Gender                      5000 non-null   object
#  5   Age                         5000 non-null   int64
#  6   Department                  5000 non-null   object
#  7   Attendance (%)              4484 non-null   float64
#  8   Midterm_Score               5000 non-null   float64
#  9   Final_Score                 5000 non-null   float64
#  10  Assignments_Avg             4483 non-null   float64
#  11  Quizzes_Avg                 5000 non-null   float64
#  12  Participation_Score         5000 non-null   float64
# ...

# %%
type(readData)
# Out:
# pandas.core.frame.DataFrame

# %%
readData.dtypes
# Out:
# Student_ID                     object
# First_Name                     object
# Last_Name                      object
# Email                          object
# Gender                         object
# Age                             int64
# Department                     object
# Attendance (%)                float64
# Midterm_Score                 float64
# Final_Score                   float64
# Assignments_Avg               float64
# Quizzes_Avg                   float64
# Participation_Score           float64
# Projects_Score                float64
# Total_Score                   float64
# Grade                          object
# Study_Hours_per_Week          float64
# Extracurricular_Activities     object
# Internet_Access_at_Home        object
# Parent_Education_Level         object
# Family_Income_Level            object
# Stress_Level (1-10)             int64
# Sleep_Hours_per_Night         float64
# dtype: object

# %%
readData.columns
# Out:
# Index(['Student_ID', 'First_Name', 'Last_Name', 'Email', 'Gender', 'Age',
#        'Department', 'Attendance (%)', 'Midterm_Score', 'Final_Score',
#        'Assignments_Avg', 'Quizzes_Avg', 'Participation_Score',
#        'Projects_Score', 'Total_Score', 'Grade', 'Study_Hours_per_Week',
#        'Extracurricular_Activities', 'Internet_Access_at_Home',
#        'Parent_Education_Level', 'Family_Income_Level', 'Stress_Level (1-10)',
#        'Sleep_Hours_per_Night'],
#       dtype='object')

# %%
readData.shape
# Out:
# (5000, 23)

# %%
readData.isnull()
readData.isnull
readData.notnull()
readData.notnull
# Out:
# <bound method DataFrame.notnull of      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com  Female   22
# 1         S1001      Maria     Brown     student1@university.com    Male   18
# 2         S1002      Ahmed     Jones     student2@university.com    Male   24
# 3         S1003       Omar  Williams     student3@university.com  Female   24
# 4         S1004       John     Smith     student4@university.com  Female   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com    Male   19
# 4996      S5996       Emma     Brown  student4996@university.com    Male   19
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4998      S5998       Sara     Davis  student4998@university.com    Male   23
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
# ...

# %%
# Select a single column from a dataframe
readData['Age']
# Out:
# 0       22
# 1       18
# 2       24
# 3       24
# 4       23
#         ..
# 4995    19
# 4996    19
# 4997    24
# 4998    23
# 4999    21
# Name: Age, Length: 5000, dtype: int64

# %%
# Select a multiple columns from a dataFrame
readData[['First_Name', 'Last_Name', 'Email', 'Gender' , 'Age']]
# Out:
#      First_Name Last_Name                       Email  Gender  Age
# 0          Omar  Williams     student0@university.com  Female   22
# 1         Maria     Brown     student1@university.com    Male   18
# 2         Ahmed     Jones     student2@university.com    Male   24
# 3          Omar  Williams     student3@university.com  Female   24
# 4          John     Smith     student4@university.com  Female   23
# ...         ...       ...                         ...     ...  ...
# 4995      Ahmed     Jones  student4995@university.com    Male   19
# 4996       Emma     Brown  student4996@university.com    Male   19
# 4997       John     Brown  student4997@university.com  Female   24
# 4998       Sara     Davis  student4998@university.com    Male   23
# 4999      Maria     Brown  student4999@university.com  Female   21
#
# [5000 rows x 5 columns]

# %%
pd = readData[readData['Age']>20]
pd
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com  Female   22
# 2         S1002      Ahmed     Jones     student2@university.com    Male   24
# 3         S1003       Omar  Williams     student3@university.com  Female   24
# 4         S1004       John     Smith     student4@university.com  Female   23
# 5         S1005       Liam     Brown     student5@university.com    Male   21
# ...         ...        ...       ...                         ...     ...  ...
# 4990      S5990        Ali   Johnson  student4990@university.com    Male   24
# 4993      S5993        Ali   Johnson  student4993@university.com  Female   22
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4998      S5998       Sara     Davis  student4998@university.com    Male   23
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
# ...

# %%
# Select a row where text column contain specific word like 'Ali'
readData[readData['First_Name']=='Ali']
readData.loc[readData['First_Name']=='Ali']

# now increasing the level of question check multiple things in it
readData[(readData['First_Name']=='Ali') & (readData['Department']=='Mathematics') & (readData['Last_Name']=='Smith') & (readData['Gender']=='Female')]
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 192       S1192        Ali     Smith   student192@university.com  Female   24
# 550       S1550        Ali     Smith   student550@university.com  Female   19
# 1155      S2155        Ali     Smith  student1155@university.com  Female   23
# 1238      S2238        Ali     Smith  student1238@university.com  Female   23
# 1997      S2997        Ali     Smith  student1997@university.com  Female   22
# 2405      S3405        Ali     Smith  student2405@university.com  Female   22
# 4871      S5871        Ali     Smith  student4871@university.com  Female   24
#
#        Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 192   Mathematics           98.35          41.17        45.82  ...
# 550   Mathematics           77.46          40.73        49.51  ...
# 1155  Mathematics           62.11          93.94        62.68  ...
# 1238  Mathematics           80.90          88.79        58.16  ...
# ...

# %%
# Select rows where columns have missing(Nan) Value
readData.isna()
# Out:
#       Student_ID  First_Name  Last_Name  Email  Gender    Age  Department  \
# 0          False       False      False  False   False  False       False
# 1          False       False      False  False   False  False       False
# 2          False       False      False  False   False  False       False
# 3          False       False      False  False   False  False       False
# 4          False       False      False  False   False  False       False
# ...          ...         ...        ...    ...     ...    ...         ...
# 4995       False       False      False  False   False  False       False
# 4996       False       False      False  False   False  False       False
# 4997       False       False      False  False   False  False       False
# 4998       False       False      False  False   False  False       False
# 4999       False       False      False  False   False  False       False
#
#       Attendance (%)  Midterm_Score  Final_Score  ...  Projects_Score  \
# ...

# %%
# fill missing value in columns with column's mean
readData.loc[:9,'Age'].mean()
readData.loc[0:, 'Age'].
# Out:
# 21.0484

# %%
readData.head(50)
# Out:
#    Student_ID First_Name Last_Name                     Email  Gender  Age  \
# 0       S1000       Omar  Williams   student0@university.com  Female   22
# 1       S1001      Maria     Brown   student1@university.com    Male   18
# 2       S1002      Ahmed     Jones   student2@university.com    Male   24
# 3       S1003       Omar  Williams   student3@university.com  Female   24
# 4       S1004       John     Smith   student4@university.com  Female   23
# 5       S1005       Liam     Brown   student5@university.com    Male   21
# 6       S1006      Ahmed     Jones   student6@university.com    Male   24
# 7       S1007      Ahmed     Smith   student7@university.com    Male   19
# 8       S1008       Omar     Smith   student8@university.com  Female   21
# 9       S1009       Sara     Smith   student9@university.com  Female   22
# 10      S1010       John     Smith  student10@university.com  Female   23
# 11      S1011       Omar  Williams  student11@university.com  Female   20
# ...

# %%
# replace occurrence of 'male' with 'M' , 'female' with 'F' in column
readData.replace({'Male':'M' , 'Female':'F'})
readData['Last_Name'] = readData['Last_Name'].replace('Ramesh', 'NewName')

# %%
# drop the row with missing value
readData.dropna()
readData.isnull()
# Out:
#       Student_ID  First_Name  Last_Name  Email  Gender    Age  Department  \
# 0          False       False      False  False   False  False       False
# 1          False       False      False  False   False  False       False
# 2          False       False      False  False   False  False       False
# 3          False       False      False  False   False  False       False
# 4          False       False      False  False   False  False       False
# ...          ...         ...        ...    ...     ...    ...         ...
# 4995       False       False      False  False   False  False       False
# 4996       False       False      False  False   False  False       False
# 4997       False       False      False  False   False  False       False
# 4998       False       False      False  False   False  False       False
# 4999       False       False      False  False   False  False       False
#
#       Attendance (%)  Midterm_Score  Final_Score  ...  Projects_Score  \
# ...

# %%
# drop specific column from dataframe
readData.drop('Age' , axis=1)
readData.drop(readData.columns[[1,3,5]],axis=1)
# Out:
#      Student_ID Last_Name  Gender   Department  Attendance (%)  Midterm_Score  \
# 0         S1000  Williams  Female  Engineering           52.29          55.03
# 1         S1001     Brown    Male  Engineering           97.27          97.23
# 2         S1002     Jones    Male     Business           57.19          67.05
# 3         S1003  Williams  Female  Mathematics           95.15          47.79
# 4         S1004     Smith  Female           CS           54.18          46.59
# ...         ...       ...     ...          ...             ...            ...
# 4995      S5995     Jones    Male     Business             NaN          82.15
# 4996      S5996     Brown    Male     Business           65.11          86.31
# 4997      S5997     Brown  Female           CS           87.54          63.55
# 4998      S5998     Davis    Male           CS           92.56          79.79
# 4999      S5999     Brown  Female  Engineering           83.92          83.24
#
# ...

# %%
# rename column name from old name to new name
readData.rename(columns={'Midterm_Score':'Mid Term Score'  })
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com  Female   22
# 1         S1001      Maria     Brown     student1@university.com    Male   18
# 2         S1002      Ahmed     Jones     student2@university.com    Male   24
# 3         S1003       Omar  Williams     student3@university.com  Female   24
# 4         S1004       John     Smith     student4@university.com  Female   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com    Male   19
# 4996      S5996       Emma     Brown  student4996@university.com    Male   19
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4998      S5998       Sara     Davis  student4998@university.com    Male   23
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
# ...

# %%
type(readData)
readData.dtypes
# Out:
# Student_ID                     object
# First_Name                     object
# Last_Name                      object
# Email                          object
# Gender                         object
# Age                             int64
# Department                     object
# Attendance (%)                float64
# Midterm_Score                 float64
# Final_Score                   float64
# Assignments_Avg               float64
# Quizzes_Avg                   float64
# Participation_Score           float64
# Projects_Score                float64
# Total_Score                   float64
# Grade                          object
# Study_Hours_per_Week          float64
# Extracurricular_Activities     object
# Internet_Access_at_Home        object
# Parent_Education_Level         object
# Family_Income_Level            object
# Stress_Level (1-10)             int64
# Sleep_Hours_per_Night         float64
# dtype: object

# %%
# Select multiple columns from a DataFrame.
readData.columns
# Out:
# Index(['Student_ID', 'First_Name', 'Last_Name', 'Email', 'Gender', 'Age',
#        'Department', 'Attendance (%)', 'Midterm_Score', 'Final_Score',
#        'Assignments_Avg', 'Quizzes_Avg', 'Participation_Score',
#        'Projects_Score', 'Total_Score', 'Grade', 'Study_Hours_per_Week',
#        'Extracurricular_Activities', 'Internet_Access_at_Home',
#        'Parent_Education_Level', 'Family_Income_Level', 'Stress_Level (1-10)',
#        'Sleep_Hours_per_Night'],
#       dtype='object')

# %%
# sort dataframe by column in ascending order
readData.sort_values(by=['Age'])
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 2499      S3499      Maria     Jones  student2499@university.com    Male   18
# 1825      S2825      Ahmed     Jones  student1825@university.com  Female   18
# 2755      S3755       Omar   Johnson  student2755@university.com    Male   18
# 3078      S4078      Ahmed     Jones  student3078@university.com    Male   18
# 595       S1595      Maria  Williams   student595@university.com  Female   18
# ...         ...        ...       ...                         ...     ...  ...
# 575       S1575       Emma     Smith   student575@university.com    Male   24
# 2757      S3757      Maria     Davis  student2757@university.com  Female   24
# 1802      S2802       John     Brown  student1802@university.com    Male   24
# 2752      S3752       Omar   Johnson  student2752@university.com    Male   24
# 1614      S2614       Emma  Williams  student1614@university.com  Female   24
#
# ...

# %%
readData.sort_values(by=['Age' , 'Final_Score'])
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 3186      S4186       John     Smith  student3186@university.com    Male   18
# 4330      S5330       Omar     Brown  student4330@university.com    Male   18
# 4099      S5099       Emma     Brown  student4099@university.com    Male   18
# 3059      S4059       Liam     Brown  student3059@university.com    Male   18
# 1001      S2001       Omar     Davis  student1001@university.com  Female   18
# ...         ...        ...       ...                         ...     ...  ...
# 3069      S4069       Sara     Smith  student3069@university.com    Male   24
# 578       S1578       Sara     Brown   student578@university.com  Female   24
# 888       S1888      Maria     Smith   student888@university.com    Male   24
# 4909      S5909       Omar     Smith  student4909@university.com  Female   24
# 956       S1956      Maria     Brown   student956@university.com    Male   24
#
# ...

# %%
# Selecting specific columns
readData['Last_Name']
# Out:
# 0       Williams
# 1          Brown
# 2          Jones
# 3       Williams
# 4          Smith
#           ...
# 4995       Jones
# 4996       Brown
# 4997       Brown
# 4998       Davis
# 4999       Brown
# Name: Last_Name, Length: 5000, dtype: object

# %%
# Convert a column of string numbers (e.g., "10", "20", "30") into integers.
df = pd.DataFrame([['1','2','3','4','5','6','7',],['11','12','13','14','15','16','18']],columns=['c1','c2','c3','c4','c5','c6','c7'])
df
df['c2'] = df['c2'].astype(int)
df
df.dtypes
# Out:
# c1    object
# c2     int32
# c3    object
# c4    object
# c5    object
# c6    object
# c7    object
# dtype: object

# %%
# Find and drop duplicate rows based on subset of a column
readData.head()
readData.drop_duplicates(subset=['Age'])
readData.drop_duplicates()
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com  Female   22
# 1         S1001      Maria     Brown     student1@university.com    Male   18
# 2         S1002      Ahmed     Jones     student2@university.com    Male   24
# 3         S1003       Omar  Williams     student3@university.com  Female   24
# 4         S1004       John     Smith     student4@university.com  Female   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com    Male   19
# 4996      S5996       Emma     Brown  student4996@university.com    Male   19
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4998      S5998       Sara     Davis  student4998@university.com    Male   23
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
# ...
